# %% [markdown]
# # Problem Description
#
# In this notebook, we explore the Service Inventory data provided by the Government of Canada on Open Government [website](https://open.canada.ca/data/en/dataset/3ac0d080-6149-499a-8b06-7ce5f00ec56c).
#
# # Obtaining Data
#
# ## Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Loading Datasets

# %%
url_inv = "https://open.canada.ca/data/dataset/3ac0d080-6149-499a-8b06-7ce5f00ec56c/resource/3acf79c0-a5f5-4d9a-a30d-fb5ceba4b60a/download/service_inventory.csv"
url_std = "https://open.canada.ca/data/dataset/3ac0d080-6149-499a-8b06-7ce5f00ec56c/resource/272143a7-533e-42a1-b72d-622116474a21/download/service_standards.csv"

# %%
df_inv = pd.read_csv(url_inv)
df_std = pd.read_csv(url_std)

# %% [markdown]
# ## Exploring Datasets: Service Identification Information & Metrics (2016-2019)

# %%
df_inv.head()
# Out:
#    fiscal_yr service_id                                    service_name_en  \
# 0  2016-2017        135                        Farm Debt Mediation Service
# 1  2016-2017        136            AgriMarketing Program Assurance Systems
# 2  2016-2017        137           AgriMarketing Program Market Development
# 3  2016-2017        138  AgriInnovation Program Industry-led Research a...
# 4  2016-2017        139  AgriInnovation Program Enabling Commercializat...
#
#                                      service_name_fr  \
# 0  Service de médiation en matière d'endettement ...
# 1  Programme Agri-marketing, volet Systèmes d'ass...
# 2  Programme Agri-marketing, volet Développement ...
# 3  Programme Agri-innovation, Activités de recher...
# 4  Programme Agri-innovation, Facilitation de la ...
#
#                  department_name_en                     department_name_fr  \
# 0  Agriculture and Agri-Food Canada  Agriculture et Agroalimentaire Canada
# 1  Agriculture and Agri-Food Canada  Agriculture et Agroalimentaire Canada
# 2  Agriculture and Agri-Food Canada  Agriculture et Agroalimentaire Canada
# 3  Agriculture and Agri-Food Canada  Agriculture et Agroalimentaire Canada
# 4  Agriculture and Agri-Food Canada  Agriculture et Agroalimentaire Canada
#
#   external_internal service_type special_designations  \
# 0            extern          res           prior,crit
# 1            extern          res                prior
# 2            extern          res                prior
# 3            extern          res                prior
# 4            extern          res                prior
#
#                               service_description_en  ... other_applications  \
# 0  Provides financial counselling and mediation s...  ...                  0
# 1  Provides funding for the development of nation...  ...                  0
# 2  Provides funding to industry associations and ...  ...                  0
# 3  Provides support for pre-commercialization Res...  ...                  0
# 4  Provides repayable contributions to approved i...  ...                  0
#
#   e_registration e_authentication e_application e_decision e_issuance  \
# 0            NaN              NaN           NaN        NaN        NaN
# 1            NaN              NaN             Y          Y          N
# 2            NaN              NaN             Y          Y          N
# 3            NaN              NaN             Y          Y          N
# 4            NaN              NaN             Y          Y          N
#
#   e_feedback client_feedback  \
# 0        NaN             NaN
# 1          N             NaN
# 2          N             NaN
# 3          N             NaN
# 4          N             NaN
#
#                                   special_remarks_en special_remarks_fr
# 0  The use of"NA" in the  SIN column is an indica...                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
#
# [5 rows x 37 columns]

# %%
df_inv.shape
# Out:
# (1865, 37)

# %%
inv_unique_program_names = df_inv.program_name_en.unique()
print("Number of unique program names:", inv_unique_program_names.size)
inv_unique_program_names
# Out:
# Number of unique program names: 661
# array(['Farm Debt Mediation Service', 'AgriMarketing', 'AgriInnovation',
#        'AgriInvest', 'AgriStability', 'Market Information and Analysis',
#        'AgriRisk Initiatives', 'Career Focus Program',
#        'AgriCompetitiveness',
#        'Career Focus Program (AYGJI is an initiaitve under te borader YES Career Focus program)',
#        'Canadian Agricultural Adaptation Program',
#        'Agricultural Greenhouse Gases', 'International Trade Shows',
#        'Market Intelligence and Information Services',
#        'Market Access Services', 'Canada Brand and Market Development',
#        "Agriculture and Agri-Food Canada Food Research and Development Centre's Industrial Program",
#        'Office of Intellectual Properities and Commercialization',
#        'Drought Watch', 'Canadian Soil Information System',
#        'Geospatial Products', 'ATIP',
#        'Churchill Port Utilization Program',
#        '  Admissibility Determination', 'Admissibility Determination',
#        ' Admissibility Determination', 'Trusted Trader',
#        'Trade Compliance', 'Trade Policy', ' Trade Policy',
#        '  Trade Compliance', '  Trade Policy', ' Trade Compliance',
#        ' Trusted Traveller', '  Trusted Traveller', 'Trusted Traveller',
#        ' Admissibility Determination - Air Mode',
#        'Admissibility Determination - Air Mode', ' Recourse', 'Recourse',
#        'Internal Services', 'Permissions', 'Information',
#        'Temporary Work Authorization',
#        'Eligibility and Admissibility Screening Status and Documents',
#        'International Students', 'International Experience Canada',
#        'Federal Skilled Workers', 'Federal Skilled Trades',
#        'Canadian Experience Class', 'Federal Business Immigrants',
#        ' Caregiver', 'Quebec Skilled Workers', 'Quebec Business',
#        'Provincial Nominees',
#        'Spouses, Partners and Children Reunification',
#        'Parents and Grandparents', 'Family and Discretionary Immigration',
#        'Humanitarian and Compassionate and Public Policy Considerations',
#        'Refugee Protection', 'In-Canada Asylum',
#        'Immigration Loan Program', 'Pre-removal Risk Assessment',
#        'Migration Control and Security Management',
#        'Newcomer Settlement and Integration',
#        'Eligibility and Admissibility Screening, Status and Documents',
#        'Identity Management', 'Resettlement Assistance Program',
#        'Interim Federal Health', 'Medical Surveillance and Notification',
#        'Citizenship Acquisition, Confirmation and Revocation',
#        'Citizenship Awareness', 'Passport',
#        'Permanent Economic Residents\r\nTemporary Economic Residents\r\nFamily and Discretionary Immigration\r\nRefugee Protection',
#        'Global Assistance to Irregular Migrants',
#        'ATIP Processing and Reporting',
#        'Permanent Economic Residents,\r\nTemporary Economic Residents,\r\nFamily and Discretionary Immigration,\r\nRefugee Protection',
#        'T1 Program', 'Taxfiler Representative Identification System',
#        'GST/HST Returns', 'GST/HST Rulings', 'T2 Program',
#        'Specialty Business Returns', 'Income Tax Rulings',
#        'Charities Directorate', 'CCB', 'GST/HST credit', 'CSA',
#        'WITB advance payments',
#        'Alberta climate leadership adjustment rebate; BC low income climate action tax credit; BC harmonized sales tax credit;New Brunswick harmonized sales tax credit; Saskatchewan low-income tax credit; Nova Scotia.',
#        'Alberta child benefit; BC family bonus; BC earned income benefit; BC early childhood tax benefit; Alberta family employment tax credit; Ontario child benefit; New Brunswick child tax benefit.',
#        'Objections', 'T3 Program', 'BN',
#        'Access to Information and Privacy', 'Learning Services', 'OAS',
#        'CPP', 'Employment Insurance and Income Benefits',
#        'EI Premium Reduction Program',
#        'EI Supplemental Unemployment Benefits Program',
#        'GC General Enquiries Telephone Service', 'GC Internet Presence',
#        'Passport Service', 'OCS', 'In-person Points of Service', 'Gs&Cs',
#        'Temporary Foreign Worker Program', 'Social Insurance Number',
#        'Job Bank', 'Work-Sharing', 'Apprenticeship Grants',
#        'Federal Income Support for Parents of Murdered or Missing Children (PMMC)',
#        'Canada Student Loans and Grants and Canada Apprentice Loans Program',
#        'Canada Education Savings Program',
#        'Labour \r\n(Occupational Health and Safety)',
#        'Wage Earner Protection Program', 'Labour',
#        'Labour (Labour Relations)', 'Labour Funding Program',
#        "Federal Workers' Compensation",
#        'Labour (Workplace Health and Safety)',
#        "Federal Workers' Compensation Program",
#        'Labour\r\n(Workplace Equity)', 'Labour \r\n(Labour Standards)',
#        'Canadian Occupational Projection System (COPS)',
#        'Canada Disability Savings Program', 'Labour Relations',
#        'Competition Law Enforcement', 'Intellectual Property',
#        'Automotive Innovation', 'Aerospace and Defense Innovation',
#        'Service for Business', 'Federal Incorporations',
#        'Trade Measurement', 'Insolvency', 'Consumer Affairs',
#        'Spectrum Management and Regulation', 'Connect to Innovate',
#        'Northern Ontario Economic Development',
#        'Acquisitions Program (Procurement Services Sub-Program)',
#        'Acquisitions Program (Build in Canada Innovation Program Sub-Program)',
#        'Acquisitions Program (Acquisitions Policy and Strategic Management)',
#        'Acquisitions Program (Engagement with Clients, Suppliers and Small and Medium Enterprises)',
#        'Federal Pay and Pensions Administration',
#        'Federal Pay and Pension Administration',
#        'Stewardship of Consolidated Revenue Fund and Accounts of Canada',
#        'Receiver General Services', 'Document Imaging Services',
#        'Federal accommodation', 'Real Property Services',
#        'Payment in Lieu of Taxes',
#        'Translation and Other Linguistic Services',
#        'Translation and Interpretation to Parliament',
#        'Conference Interpretation', 'Terminology Standardization Program',
#        'Contract Security', 'Integrity Framework', 'Controlled Goods',
#        'Fairness Monitoriing and Business Dispute Management',
#        'Government of Canada Administrative Services Sub-Program',
#        'Government of Canada Administration Services Sub-Program',
#        'Standards Development and Certification', 'Asset Disposal',
#        'Shared Travel Services', 'Government Information Services',
#        'Email and Mobile Enterprise Server Services',
#        'Data Network Infrastructure Services', 'Voice Network Services',
#        'Conferencing Services', 'Contact/Call Centre Services',
#        'Utility Computing Services',
#        'Desktop and Office Productivity Suite Services',
#        'File/Print Services',
#        'Data Network Infrastructure Services, Inter- and Intra-Data Centre Network Services',
#        'Voice Network Services,                                                  Conferencing Services',
#        'Identification, Authentication and Authorization Services',
#        'Remote Access Services,                              Identification, Authentication and Authorization Services,\r\nSecure Communication Services',
#        'Workstation Services',
#        'Data Network Infrastructure Services, Inter- and Intra-Data Centre Network Services,                                                           Voice Network Services',
#        'Desktop and Office Productivity Suite Services,                                                            File/Print Services',
#        'Utility Computing Services,                          Dedicated Application Hosting and Management Services',
#        'Utility Computing Services,                          Dedicated Application Hosting and Management Services,                     Facilities Management Services',
#        'Financial Support Program', 'Disability Benefits',
#        'Health Care Program and Re-establishment Services',
#        'Disability and Death Compensation', nan,
#        'Canada Remembers Program', 'AgriScience', 'AgriInnovate',
#        'Global Market Information and Analysis', 'Market Access',
#        'Canada Brand', 'Canada Pavilion Program',
#        'Diary Processing Investement Fund', 'Dairy Farm Investment',
#        'Exportation of Cultural Property', 'Temporary Workers',
#        'Visitors', 'Federal Economic Immigration',
#        'Provincial Economic Immigration', 'Family Reunification',
#        'Humanitarian / Compassionate and Discretionary Immigration',
#        'Resettled Refugees', 'Asylum', 'Settlement',
#        'Refugee Resettlement', 'Citizenship',
#        "Alberta climate leadership adjustment rebate; BC climate action tax credit; BC harmonized sales tax credit;New Brunswick harmonized sales tax credit; Newfoundland and Labardor Income Supplement; Nova Scotia Affordable Living Tax Credit, Ontario Trillium Benefit; Ontario Senior Homeowners' Property Tax Grant,; PEI Sales Tax Credit; Saskatchewan low-income tax credit.",
#        'Alberta Family Employment Tax Credit; Alberta child benefit; BC family bonus; BC earned income benefit; BC early childhood tax benefit; New Brunswick Child Tax Benefit; Newfoundland and Labrador Child Benefit; Nunavut Child Benefit; Northwest Territories Child Benefit; Nova Scotia Child Benefit; Ontario child benefit; Saskatchewan Child Benefit; Yukon Child Benefit.',
#        'Old Age Security', 'Employment Insurance',
#        'Government of Canada Telephone General Enquiries Services',
#        'Government of Canada Internet Presence',
#        'Administration of Grants and Contributions (Gs&Cs) for Employment and Social Development Programs',
#        'Federal Income Support for Parents of Murdered or Missing Children',
#        'Occupational Health and Safety',
#        'Workplace Equity\r\n\r\nInternational Labour Affairs\r\n\r\nOccupational Health and Safety',
#        'Workplace Equity', 'Labour Standards', 'Canada Pension Plan',
#        'The Automotive Supplier Innovation Program',
#        'Automotive Innovation Fund',
#        'Strategic Aerospace and Defence Initiative (SADI)',
#        'Technology Demonstration Program (TDP)',
#        'Strategic Innovation Fund', 'Innovation Superclusters Initiative',
#        'Clean Growth Hub', 'Procurement Services',
#        'Build in Canada Innovation Program',
#        'Acquisitions Policy and Strategic Management',
#        'Engagement with Clients, Suppliers and Small and Medium Enterprises',
#        'Fairness Monitoring and Business Dispute Management',
#        'Government of Canada Administrative Services', 'Integrity Regime',
#        'Email and Workplace Technology', 'Telecommunications',
#        'Data Centres', 'Cyber and IT Security',
#        'Brokered Public Cloud Services', 'Career Impact Allowance',
#        'Family Caregiver Relief Benefit', 'Long Term Care',
#        'Health Care Benefits', 'Veterans Independence Program',
#        'Canadain Forces Income Support', 'Earnings Loss Benefit',
#        'Retirement Benefits', 'War Veterans Allowance',
#        'Transition Services - Rehabilitation',
#        'Transition Services - CTS', 'Funeral and Burial Program',
#        'Transition Services - ETB', 'Veterans Emergency Fund',
#        'Transition Services - Veteran Family Program',
#        'Canada Remembers Program ', 'Retirement Income Security Benefit',
#        'Permissions for Plant Products,Permissions for Animal Products,Permissions for Food Products',
#        'Fisheries Management', 'Email Services',
#        'Human Resources Management Services',
#        'Land, Natural Resources and Environmental Management',
#        'Permissions for Plant Products,Permissions for Animal Products,Permissions for Food Products,Communications Services',
#        'Disability Awards, Critical Injury and Death Benefits,Health Care Benefits,Transition Services,Long Term Care,Veterans Independence Program,Caregiver Recognition Benefit,Veterans Emergency Fund,Funeral and Burial Program',
#        'Intermodal Surface Security Oversight', 'Communications Services',
#        'Regulation and Guidance of Federally Regulated Financial Institutions',
#        'Multi-Modal and Road Safety Oversight Program',
#        'Indigenous Governance and Capacity',
#        'High Performance Computing Solution',
#        'Platform Corporate Services', 'Learning',
#        'Innovation,Business Growth,Business Services,Community Initiatives,Internal Services',
#        'Toll-Free Voice', 'Bulk Print', 'Refugee Appeal Decisions',
#        'Maintenance of infrastructure and security',
#        'Health Promotion,Chronic Disease Prevention,Emergency Preparedness and Response',
#        'Educational, cultural and heritage activities',
#        'Conservation and Protection', 'Mainframe', 'Storage',
#        'Specialized Health Services and Internationally Protected Persons Program',
#        'International Assistance Operations,Multilateral International Assistance,Europe, Arctic, Middle East and Maghreb International Assistance,Americas International Assistance,Asia Pacific International Assistance,Sub-Saharan Africa International Assistance',
#        'Satellite', 'Tax Services and Processing',
#        'Clean Growth and Climate Change Mitigation', 'Cloud',
#        'Marine Planning and Conservation', 'Community Engagement',
#        'Multilateral Policy,Europe, Arctic, Middle East and Maghreb Policy & Diplomacy,Americas Policy & Diplomacy,Asia Pacific Policy & Diplomacy,International Business Development,Trade, Investment and International Economic Policy',
#        'Fish and Fish Habitat Protection',
#        'International Law,Legal Services',
#        'Analysis and Outreach,Dispute Resolution,Determinations and Compliance,Internal Services',
#        'Sector Engagement and Development',
#        'Foundational Science and Research', 'Police Operations',
#        'Federal Incorporation', 'Indigenous Languages and Cultures',
#        'Trade and Market Expansion', 'AgriRisk',
#        'Real Property Project Delivery, Professional and Technical Services,Mission Readiness and Security',
#        'Agricultural Greenhouse Gases Program',
#        'Northern Projects Management',
#        'Investing in Canada Phase 1 - Funding for Federation of Canadian Municipalities',
#        'Arts', 'Dairy Programs', 'Assurance Program',
#        'Indigenous Entrepreneurship and Business Development',
#        'Nuclear Non-Proliferation Program', 'Commissions of Inquiry',
#        'Dispute Resolution,Internal Services',
#        'Mobile Devices and Fixed-Line Phones', 'Small Craft Harbours',
#        'Analysis and Outreach,Determinations and Compliance,Internal Services',
#        'Crime Prevention,Law Enforcement and Policing,Indigenous Policing',
#        'Disability Pension Benefits and Allowances,Disability Awards, Critical Injury and Death Benefits,Health Care Benefits,Long Term Care,Veterans Independence Program,War Veterans Allowance,Veterans Emergency Fund,Funeral and Burial Program',
#        'Protection Program',
#        'Nuclear Substances and Prescribed Equipment Program',
#        'Species at Risk',
#        'Insight Research,Research Partnerships,New Frontiers in Research Fund',
#        'Infrastructure, Tolls and Export Applications',
#        'Emergency Management Assistance',
#        'Management and Oversight Services', 'Biosecurity',
#        'National Security Leadership,Critical Infrastructure,Cyber Security',
#        'Security and Oversight Services', 'Controlled Substances',
#        'Environmental Response', 'Emergency Response/Recovery',
#        'Management and Implementation of Agreements and Treaties',
#        'Aviation Safety Certification', 'Transportation Infrastructure',
#        'Icebreaking Services', 'Information Management Services',
#        'Migratory Birds and Other Wildlife',
#        'Marine Communications and Traffic Services',
#        'Heritage Places Establishment,Heritage Places Conservation,Heritage Places Promotion and Public Support,Visitor Experience',
#        'Aviation Safety Regulatory Framework',
#        'Oversight and Monitoring,Internal Services',
#        'Heritage Places Establishment,Heritage Places Conservation,Heritage Places Promotion and Public Support,Visitor Experience,Heritage Canals, Highways and Townsites Management,Management and Oversight Services',
#        'Policy Direction and Support', 'Entrepreneurship Policy',
#        'Cultural Industries Support and Development',
#        'Law Enforcement and Policing',
#        'Substances and Waste management,Compliance Promotion and Enforcement - Pollution',
#        'Search and Rescue', 'Community Eco-Action',
#        'Innovation,Business Growth,Business Services,Community Initiatives',
#        'Policy Direction and Support,Recruitment and Assessment Services',
#        'Water Quality and Ecosystems Partnerships',
#        'Regulation and Guidance of Federally Regulated Financial Institutions,Regulatory Approvals and Legislative Precedents',
#        'Crime Prevention',
#        'Critical Infrastructure,Cyber Security,Emergency Prevention/Mitigation,Emergency Preparedness',
#        'Admissibility and Detention Decisions',
#        'Immigration Appeal Decisions',
#        'Stakeholder Engagement,Indigenous Engagement,Infrastructure, Tolls and Export Applications',
#        'Waterways Management',
#        'Heritage Places Promotion and Public Support,Visitor Experience',
#        'Pesticides',
#        'Heritage Places Establishment,Heritage Places Conservation,Heritage Places Promotion and Public Support,Visitor Experience,Heritage Canals, Highways and Townsites Management,Communications Services',
#        'Cannabis', 'Cost-Recovered Statistical Services',
#        'Spectrum and Telecommunications',
#        'Inclusive Communities,Diversified Communities,Research and Development and Commercialization,Innovation Ecosystem,Business Growth,Trade and Investment,Policy Research and Engagement',
#        'Economic and Environmental Statistics,Socio-economic Statistics,Censuses,Cost-Recovered Statistical Services',
#        'Water and Wastewater', 'Preservation,Public services', 'Benefits',
#        'Recruitment and Assessment Services', 'Transition Services',
#        'Aircraft Services', 'Payments pursuant to the Judges Act',
#        'Housing', 'Acquisition and processing of government records',
#        'Consultation and Accommodation', 'Internet',
#        'Actuarial Valuation and Advice', 'Complaints Resolution',
#        'Marine Safety Oversight', 'Identity and Access Management',
#        'Commercial-Trade Facilitation and Compliance',
#        'Federal Judicial Affairs', 'Compliance Program',
#        'International Policy Coordination,Multilateral Policy,International Law,The Office of Protocol,Europe, Arctic, Middle East and Maghreb Policy & Diplomacy,Americas Policy & Diplomacy,Asia Pacific Policy & Diplomacy,Sub-Saharan Africa Policy & Diplomacy,Geographic Coordination and Mission Support,Gender Equality and the Empowerment of Women and Girls,Growth that works for everyone,Humanitarian Action,Human Development: Health & Education,Environment and Climate Action,Human Rights, Governance, Democracy & Inclusion,Peace and Security Policy,Trade Policy, Agreements, Negotiations and Disputes,Trade Controls,International Business Development,International Innovation and Investment,Europe, Arctic, Middle East and Maghreb Trade,Americas Trade,Asia Pacific Trade,Sub-Saharan Africa Trade,International Assistance Operations,Humanitarian Assistance,Partnerships and Development Innovation,Multilateral International Assistance,Peace and Stabilization Operations,Anti-Crime and Counter-Terrorism Capacity Building,Weapons Threat Reduction,Canada Fund for Local Initiatives,Europe, Arctic, Middle East and Maghreb International Assistance,Americas International Assistance,Asia Pacific International Assistance,Sub-Saharan Africa International Assistance,Grants and Contributions Policy and Operations,Consular Assistance and Services for Canadians,Emergency Preparedness and Response,Platform Corporate Services,Foreign Service Directives,Client Relations and Mission Operations,Locally Engaged Staff Services,Real Property Planning and Stewardship,Real Property Project Delivery, Professional and Technical Services,Mission Readiness and Security,Mission Network IM/IT,Trade, Investment and International Economic Policy,Management and Oversight Services,Communications Services,Legal Services,Human Resources Management Services,Financial Management Services,Information Management Services,Information Technology Services,Real Property Management Services,Materiel Management Services,Acquisition Management Services',
#        'Transportation of Dangerous Goods Oversight', 'Mid-Range',
#        'Military History and Heritage', 'Financial Management Services',
#        'Disability Pension Benefits and Allowances,Earnings Loss Benefit',
#        'Wide Area Network', 'Food & Nutrition',
#        'Defence Materiel Management',
#        'Copyright Tariff Setting and Issuance of Licences',
#        'Investing in Canada Phase 1 - Funding Allocations for Provinces and Territories',
#        'Investing in Canada Infrastructure Program',
#        'Heritage Places Conservation,Visitor Experience,Heritage Canals, Highways and Townsites Management',
#        'Disability Pension Benefits and Allowances,Disability Awards, Critical Injury and Death Benefits,Health Care Benefits,Transition Services,Long Term Care,Veterans Independence Program,Caregiver Recognition Benefit,War Veterans Allowance,Veterans Emergency Fund,Veteran and Family Well Being Fund,Funeral and Burial Program',
#        'Discovery Research,Research Training and Talent Development,Research Partnerships',
#        'Canada Student Loans Program and Canada Apprentice Loans',
#        'Transportation of Dangerous Goods Technical Support',
#        'Heritage Places Conservation,Heritage Places Promotion and Public Support,Visitor Experience,Heritage Canals, Highways and Townsites Management,Real Property Management Services',
#        'Environmental Sustainability and Protection',
#        'Secret Infrastructure', 'Historical Programs',
#        'National Security Leadership', 'Local Area Network',
#        'Learning About Canadian History',
#        'Explosives Safety and Security',
#        'Support and Financing for Small Business',
#        'Training and Career Support,Research in Priority Areas,Financial Management Services',
#        'Heritage Places Conservation,Heritage Canals, Highways and Townsites Management,Real Property Management Services',
#        'Health Care Systems Analysis and Policy',
#        'Federal Pay Administration,Federal pension Administration',
#        'Canadian Forces Liaison Council and Employer Support',
#        'Radiation Protection', 'Government-wide Corporate Services',
#        'Communications Services,Information Management Services',
#        'Registry Services', 'Charities', 'Individual Affairs',
#        'Competition Law Enforcement and Promotion', 'Space Utilization',
#        'Refugee Protection Decisions', 'Marine Safety Certification',
#        'Promotion of works and National Film Board outreach',
#        'Statutory, Legislative and Policy Support to First Nations Governance',
#        'Preservation, conservation and digitization of works',
#        'Canadian Judicial Council',
#        'Heritage Places Establishment,Heritage Places Conservation,Heritage Places Promotion and Public Support,Visitor Experience,Heritage Canals, Highways and Townsites Management',
#        'Youth Justice', 'Justice System Partnerships',
#        'Marine Safety Oversight,Marine Safety Certification',
#        'Indigenous Justice',
#        'Senior Personnel and Public Service Renewal,International Affairs and National Security,Planning and Operation of Cabinet,Youth,Legislative and Parliamentary Governance,Results, Delivery, Impact and Innovation,Intergovernmental Affairs,Social and Economic Policy',
#        'Protection Within the Communications System',
#        'Traveller Facilitation and Compliance',
#        'Aboriginal Programs and Treaties', 'Visitor Experience',
#        'Migratory Birds and Other Wildlife,Habitat Conservation and Protection',
#        'Science, Technology and Innovation',
#        'Disability Pension Benefits and Allowances,Disability Awards, Critical Injury and Death Benefits,Health Care Benefits,Veterans Independence Program,War Veterans Allowance',
#        'Economic and Environmental Statistics',
#        'Conditional Release Openness and Accountability',
#        'New Building Canada Fund - National Infrastructure Component',
#        'Audit Program', 'Critical Infrastructure,Emergency Preparedness',
#        'Indigenous Policing', 'Cyber Security',
#        'Information Technology Services',
#        'Insight Research,Research Training and Talent Development,Research Partnerships,New Frontiers in Research Fund,Research Support Fund',
#        'Research Training and Talent Development',
#        'Canadian Agricultural Strategic Priorities Program',
#        'Navigation Protection Program',
#        'Supervision and Promotion,Financial Literacy',
#        'Anti-Dumping and Countervailing', 'Rail Safety Oversight',
#        'Disability Pension Benefits and Allowances,Disability Awards, Critical Injury and Death Benefits,Transition Services,Long Term Care,Caregiver Recognition Benefit',
#        'Serious and Organized Crime',
#        'Home, Community and Palliative Care',
#        'Aviation Occurrence Investigations,Marine Occurrence Investigations,Rail Occurrence Investigations,Pipeline Occurrence Investigations',
#        'Emergency Prevention/Mitigation,Emergency Preparedness,Emergency Response/Recovery',
#        'Thalidomide',
#        'Aviation Security Regulatory Framework,Aviation Security Oversight',
#        'National Security Leadership,Critical Infrastructure,Cyber Security,Crime Prevention,Law Enforcement and Policing,Serious and Organized Crime,Border Policy,Indigenous Policing,Corrections,Emergency Prevention/Mitigation,Emergency Preparedness,Emergency Response/Recovery',
#        'Policy, Rulings, and Interpretations', 'Middleware & Database',
#        'Secure Remote Access',
#        'Hardware Provisioning,Software Provisioning',
#        'National Security Leadership,Critical Infrastructure,Cyber Security,Emergency Prevention/Mitigation,Emergency Preparedness,Information Technology Services',
#        'Consumer Product Safety,Workplace Hazardous Products',
#        'Real Property Management Services',
#        'Payments and Revenue Collection',
#        'Reaching Home,Social Development Partnerships Program,New Horizons for Seniors Program,Enabling Accessibility Fund,Early Learning and Child Care,Indigenous Early Learning Child Care Transformation Initiative,Opportunities Fund for Persons with Disabilities,Youth Employment Strategy,Canada Service Corps,Skills and Partnership Fund,Literacy and Essential Skills,Indigenous Skills and Employment Training (ISET) Program,Student Work Placement Program,Union Training and Innovation Program,Sectoral Initiatives Program,Foreign Credential Recognition Program,Enabling Fund for Official Language Minority Communities',
#        'Visitor Experience,Heritage Canals, Highways and Townsites Management',
#        'Procurement Leadership',
#        'Linguistic services,Communication Services',
#        'Linguistic services', 'Education',
#        'Consular Assistance and Services for Canadians,Emergency Preparedness and Response',
#        'National Security Leadership,Crime Prevention',
#        'Talent Development', 'Objections and Appeals',
#        'Financial Management Policies and Initiatives',
#        'Inclusive Communities,Diversified Communities',
#        'Economic and Environmental Statistics,Socio-economic Statistics,Censuses',
#        'International Business Development', 'Corrections',
#        'Protecting Oceans and Waterways',
#        'Visitors,International Students,Temporary Workers',
#        'Disaster Mitigation and Adaption Fund', 'Smart Cities Challenge',
#        'Transportation Innovation',
#        'Federal Accommodation and Infrastructure',
#        'Inclusive Communities,Diversified Communities,Research and Development and Commercialization,Innovation Ecosystem,Business Growth,Trade and Investment,Policy Research and Engagement,Internal Services',
#        'National Science Library', 'National Trade Corridors',
#        'Habitat Conservation and Protection',
#        'Heritage Places Establishment,Heritage Places Conservation,Management and Oversight Services,Real Property Management Services',
#        'Critical Infrastructure,Cyber Security,Emergency Preparedness',
#        'Consultation and Policy Development',
#        "Consultation and Policy Development,Federal Interlocutor's Contribution Program,Basic Organizational Capacity",
#        'Critical Infrastructure,Cyber Security', 'Aids to Navigation',
#        'Knowledge Management and Engagement', 'Science and Technology',
#        'Aquaculture Management',
#        'Consular Assistance and Services for Canadians,Emergency Preparedness and Response,Communications Services',
#        'New Building Canada Fund - Funding Allocations for Provinces and Territories',
#        'National Security Leadership,Crime Prevention,Law Enforcement and Policing',
#        'Heritage Places Conservation,Visitor Experience',
#        'Occupational Health and Safety,Workplace Equity,International Labour Affairs',
#        'Climate Change Adaptation and Clean Energy',
#        'In-Person Points of Service',
#        'Explosives Safety and Security,Clean Energy Technology Policy, Research and Engagement',
#        'Individual Training and Professional Military Education,Management and Oversight Services,Communications Services',
#        'Border and Travel Health', 'Contact Centre Infrastructure',
#        'Policy Direction and Support,Recruitment and Assessment Services,Oversight and Monitoring',
#        'Investigator-Initiated Research,Training and Career Support,Research in Priority Areas',
#        'Clinical and Client Care', 'Emergency Preparedness and Response',
#        'Socio-economic Statistics', 'Energy Efficiency',
#        'Humanitarian/Compassionate and Discretionary Immigration',
#        'Compliance Program,Strategic Policy and Reviews,Financial Intelligence Program,Strategic Intelligence, Research and Analytics',
#        'Financial Intelligence Program',
#        'Economic Development in Northern Ontario',
#        'Supplementary Health Benefits', 'Assisted Living',
#        'Income Assistance', 'Family Violence Prevention',
#        'Workplace Policies and Services,Human Resources Management Services',
#        'Heritage Places Establishment,Heritage Places Conservation,Visitor Experience,Management and Oversight Services,Communications Services,Legal Services,Information Technology Services',
#        'Canadian General Standards Board', 'Review and Appeal',
#        'Urban Programming for Indigenous Peoples',
#        'Emergency Preparedness', 'Participant Funding',
#        'Community Development,Business Development',
#        'Conference Services',
#        'Acquisition and processing of published heritage,Preservation',
#        'Herzberg Astronomy & Astrophysics',
#        'Business innovation and growth,Vitality of communities,Targeted or temporary support',
#        'Rail Safety Improvement Program',
#        'Canadian Benefit for Parents of Young Victims of Crime,Old Age Security,Canada Pension Plan,Employment Insurance,Job Bank,Apprenticeship Grants,Passport',
#        'Real Property Project Delivery, Professional and Technical Services',
#        'Acquisition and processing of published heritage',
#        'Bridging Digital Divides', 'Ombudsman for federal offenders',
#        'Community Oral Health Services', 'Innovation in Business',
#        'Indigenous Partnerships and Engagement',
#        'Transportation Marketplace Frameworks', 'Emergency Management',
#        'Crime Prevention,Law Enforcement and Policing,Serious and Organized Crime',
#        'Climate Change and Clean Air',
#        'Payments Instead of Property Taxes to Local Governments',
#        'Nutrition North', "Child First Initiative – Jordan's Principle",
#        'Clean Energy Technology Policy, Research and Engagement',
#        'Real Property Planning and Stewardship', 'Metrology',
#        'Oversight and Monitoring',
#        'Energy Safety and Security, and Petroleum Resources',
#        'Provision of Federal Leadership in the Minerals and Metals Sector',
#        'Assessment Delivery', 'Client Relations and Mission Operations',
#        'International Assistance Operations',
#        'Outreach and support to communities',
#        'Trade Policy, Agreements, Negotiations and Disputes,Trade Controls,Europe, Arctic, Middle East and Maghreb Trade,Americas Trade,Asia Pacific Trade,Sub-Saharan Africa Trade,Trade, Investment and International Economic Policy,Materiel Management Services',
#        'International Policy Coordination,Growth that works for everyone,Trade Policy, Agreements, Negotiations and Disputes,Trade Controls,International Business Development,Europe, Arctic, Middle East and Maghreb Trade,Americas Trade,Asia Pacific Trade,Sub-Saharan Africa Trade,Weapons Threat Reduction,Trade, Investment and International Economic Policy,Management and Oversight Services,Financial Management Services,Information Management Services,Information Technology Services',
#        'International Law,Consular Assistance and Services for Canadians',
#        'Public services', 'Pharmaceutical Drugs', 'Healthy Living',
#        'Heritage Places Establishment,Heritage Places Conservation,Heritage Places Promotion and Public Support,Visitor Experience,Heritage Canals, Highways and Townsites Management,Legal Services,Real Property Management Services',
#        'Disability Pension Benefits and Allowances,Disability Awards, Critical Injury and Death Benefits',
#        'Energy and Climate Change Policy', 'Legal Services',
#        "Federal Interlocutor's Contribution Program",
#        'Home and Community Care', 'Core Geospatial Data',
#        'Insight Research,Research Support Fund',
#        'Space Capacity Development', 'Oceans and Climate Change Science',
#        'Censuses', 'Construction',
#        'Space Utilization,Space Capacity Development',
#        'Official Languages',
#        'Promoting Minority Official Languages in the Health Care Systems',
#        'Investigator-Initiated Research,Training and Career Support,Research in Priority Areas,Financial Management Services',
#        'Research and Development and Commercialization,Innovation Ecosystem,Business Growth,Trade and Investment',
#        'Financial Literacy', 'Health Human Resources',
#        'Economic Development Capacity and Readiness', 'Health Facilities',
#        'Healthy Child Development',
#        'Canadian Benefit for Parents of Young Victims of Crime',
#        'Industrial Research Assistance Program',
#        'Environmental Public Health',
#        'Scientific, Regulatory and Public Information Program',
#        'Northern and Arctic Environmental Sustainability',
#        'Cadets and Junior Canadian Rangers (Youth Program)',
#        'British Columbia Tripartite Health Governance,Health Planning, Quality Management and Systems Integration',
#        'Europe, Arctic, Middle East and Maghreb Policy & Diplomacy,Americas Policy & Diplomacy,Asia Pacific Policy & Diplomacy,Sub-Saharan Africa Policy & Diplomacy,Europe, Arctic, Middle East and Maghreb Trade,Americas Trade,Asia Pacific Trade,Sub-Saharan Africa Trade,Platform Corporate Services',
#        'Laboratory Science Leadership and Services',
#        'First Nation Jurisdiction over Land and Fiscal Management',
#        'Toronto Waterfront Revitalization Initiative',
#        'Record Suspension Decisions/Clemency Recommendations',
#        'Education Facilities',
#        'Other Community Infrastructure and Activities',
#        'Organs, Tissues and Blood', 'Mental Wellness',
#        'Clean Growth and Climate Change Mitigation,Climate Change Adaptation',
#        'Gas Tax Fund - Permanent Funding for Municipalities',
#        'Communicable Diseases Control and Management',
#        'Health Planning, Quality Management and Systems Integration',
#        'e-Health Infostructure',
#        'First Nations Child and Family Services',
#        'Substances and Waste management',
#        'Water Quality and Ecosystems Partnerships,Compliance Promotion and Enforcement - Pollution',
#        'Water Quality and Ecosystems Partnerships,Compliance Promotion and Enforcement - Wildlife,Weather and Environmental Observations, Forecasts and Warnings',
#        'Laboratory Science Leadership and Services,Emergency Preparedness and Response,Biosecurity',
#        'Impact Assessment Policy Development,Assessment Delivery',
#        'Employment Conditions and Labour Relations,Human Resources Management Services',
#        'Tobacco Control', 'Substance Use and Addictions',
#        'Medical Devices', 'Health Information',
#        'Old Age Security,Canada Pension Plan,Employment Insurance',
#        'Natural Health Products',
#        'Pharmaceutical Drugs,Biologics & Radiopharmaceutical Drugs,Medical Devices',
#        'Victims of Crime', 'Hydrological Services', 'Air Quality',
#        'Weather and Environmental Observations, Forecasts and Warnings',
#        'Compliance Promotion and Enforcement - Pollution',
#        'Emergency Prevention/Mitigation,Emergency Response/Recovery',
#        'Emergency Response/Recovery,Communications Services',
#        'Disability Pension Benefits and Allowances,Disability Awards, Critical Injury and Death Benefits,Earnings Loss Benefit,Career Impact Allowance,Health Care Benefits,Transition Services,Long Term Care,Veterans Independence Program,Caregiver Recognition Benefit,War Veterans Allowance,Veterans Emergency Fund,Centre of Excellence on Post Traumatic Stress Disorder and Related Mental Health Conditions,Veteran and Family Well Being Fund,Funeral and Burial Program',
#        'Preservation of and Access to Heritage',
#        'Cultural Marketplace Framework',
#        'National Celebrations, Commemorations and Symbols',
#        'Disability Pension Benefits and Allowances,Health Care Benefits,Long Term Care,Veterans Independence Program,War Veterans Allowance,Veterans Emergency Fund,Funeral and Burial Program',
#        'Sport Development and High Performance', 'Multiculturalism',
#        'Community Engagement and Heritage',
#        'Hydrographic Services, Data and Science',
#        'Clean Technology and Clean Growth',
#        'Canadian Geodetic Survey: Spatially Enabling Canada,Core Geospatial Data',
#        'Canada Lands Survey System', 'Wildfire Risk Management',
#        'Major Projects Management Office Initiative',
#        'Geoscience to Keep Canada Safe',
#        'Veteran and Family Well Being Fund',
#        'Disability Awards, Critical Injury and Death Benefits',
#        'Disability Pension Benefits and Allowances,Disability Awards, Critical Injury and Death Benefits,Health Care Benefits,Long Term Care,War Veterans Allowance',
#        'Industrial Research Assistance Program,Communications Services',
#        'Aerospace,Aquatic and Crop Resource Development,Automotive and Surface Transportation,Construction,Energy, Mining and Environment,Herzberg Astronomy & Astrophysics,Human Health Therapeutics,Information and Communications Technologies,Metrology,Medical Devices,Nanotechnology,Ocean, Coastal and River Engineering,Security and Disruptive Technologies'],
#       dtype=object)

# %%
inv_unique_department_names = df_inv.department_name_en.unique()
print("Number of unique department names:", inv_unique_department_names.size)
inv_unique_department_names
# Out:
# Number of unique department names: 67
# array(['Agriculture and Agri-Food Canada',
#        'Canada Border Services Agency', 'Canadian Food Inspection Agency',
#        'Immigration, Refugees and Citizenship Canada',
#        'Canada Revenue Agency', 'Canada School of Public Service',
#        'Employment and Social Development Canada',
#        'Innovation, Science and Economic Development Canada',
#        'Public Services and Procurement Canada', 'Shared Services Canada',
#        'Veterans Affairs Canada', 'Fisheries and Oceans Canada',
#        'Crown-Indigenous Relations and Northern Affairs Canada',
#        'Transport Canada', 'Public Health Agency of Canada',
#        'Office of the Superintendent of Financial Institutions Canada',
#        'Department of Indigenous Services', 'Public Safety Canada',
#        'Global Affairs Canada', 'Western Economic Diversification Canada',
#        'The National Battlefields Commission',
#        'Immigration and Refugee Board of Canada', 'Health Canada',
#        'Environment and Climate Change Canada',
#        'Correctional Service Canada', 'Canadian Transportation Agency',
#        'Royal Canadian Mounted Police', 'Canadian Heritage',
#        'Farm Products Council of Canada',
#        'Canadian Northern Economic Development Agency',
#        'Infrastructure Canada', 'Canadian Nuclear Safety Commission',
#        'Privy Council Office', 'Canadian Human Rights Commission',
#        'Social Sciences and Humanities Research Council of Canada',
#        'Canada Energy Regulator', 'Parks Canada',
#        'Public Service Commission of Canada', 'Statistics Canada',
#        'Atlantic Canada Opportunities Agency',
#        'Library and Archives Canada',
#        'Office of the Commissioner for Federal Judicial Affairs Canada',
#        'Military Police Complaints Commission of Canada',
#        'Financial Transactions and Reports Analysis Centre of Canada',
#        'Canada Economic Development for Quebec Regions',
#        'National Defence', 'Copyright Board Canada',
#        'Natural Sciences and Engineering Research Council of Canada',
#        'Natural Resources Canada',
#        'Canadian Institutes of Health Research', 'Canadian Space Agency',
#        'Administrative Tribunals Support Service of Canada',
#        'National Film Board', 'Department of Justice Canada',
#        'Canadian Radio-television and Telecommunications Commission',
#        'Parole Board of Canada', 'Treasury Board of Canada Secretariat',
#        'Financial Consumer Agency of Canada',
#        'Transportation Safety Board of Canada',
#        'National Research Council Canada',
#        'Courts Administration Service', 'Polar Knowledge Canada',
#        'Patented Medicine Prices Review Board Canada',
#        'Veterans Review and Appeal Board',
#        'Canadian Intergovernmental Conference Secretariat',
#        'The Correctional Investigator Canada',
#        'Impact Assessment Agency of Canada'], dtype=object)

# %%
inv_uique_service_names = df_inv.service_name_en.unique()
print("Number of unique service names:", inv_uique_service_names.size)
inv_uique_service_names
# Out:
# Number of unique service names: 1337
# array(['Farm Debt Mediation Service',
#        'AgriMarketing Program Assurance Systems',
#        'AgriMarketing Program Market Development', ...,
#        'ATIP Compliance Services',
#        'Calibration laboratory assessment service',
#        'Instrument Calibration Services'], dtype=object)

# %%
df_inv.service_type.unique()
# Out:
# array(['res', 'adv', 'reg', 'legal', 'hr', 'ecu', 'acq', 'its', 'fm',
#        'im', 'rule', 'comm', 'mat', 'mgnt', 'reg_vol', 'ecu,reg',
#        'adv,reg', 'adv,ecu', 'gnc', 'adv,mgnt', 'adv,comm', 'its,mgnt',
#        'mgnt,adv', 'mgnt,mat', 'rule,legal', 'reg_vol,reg', 'reg,ecu',
#        'res,gnc', 'prop', 'reg,comm', 'reg,reg_vol', 'gnc,res', 'ecu,adv',
#        'im,hr', 'mgnt,res', 'mgnt,reg', 'adv,hr', 'im,adv', 'adv,gnc',
#        'reg,adv', 'rule,reg', 'adv,fm', 'res,reg', 'adv,res', 'reg,res',
#        'gnc,fm', 'im,its', 'im,comm', 'mgnt,ecu', 'legal,comm',
#        'its,comm', 'its,reg', 'reg,hr', 'comm,adv', 'reg,gnc', 'gnc,ecu',
#        'mgnt,prop', 'ecu,gnc', 'reg,its', 'hr,reg', 'im,ecu', 'mgnt,hr',
#        'comm,reg', 'adv,prop', 'mgnt,fm', 'comm,res', 'adv,legal',
#        'reg,prop', 'fm,gnc', 'its,res', 'acq,adv', 'res,prop',
#        'reg_vol,adv', 'mat,res'], dtype=object)

# %%
#Random cell to test
##HI!
